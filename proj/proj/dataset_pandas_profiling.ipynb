# %%
from ydata_profiling import ProfileReport

# %%
import pandas as pd

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5572  4654-ULTTN    Male              0     Yes         No      70
# 1841  8958-JPTRR  Female              0     Yes         No      56
# 2041  3546-GHEAE    Male              0      No         No       7
# 1521  9207-ZPANB    Male              0      No         No      37
# 505   5609-CEBID  Female              1      No         No      20
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 5572          Yes           Yes             DSL                  Yes  ...
# 1841          Yes           Yes              No  No internet service  ...
# 2041          Yes            No              No  No internet service  ...
# 1521          Yes           Yes             DSL                  Yes  ...
# 505           Yes           Yes     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 5572                  Yes                  Yes                   No
# 1841  No internet service  No internet service  No internet service
# 2041  No internet service  No internet service  No internet service
# 1521                  Yes                  Yes                   No
# 505                   Yes                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 5572                  Yes        Two year              Yes
# 1841  No internet service        One year               No
# 2041  No internet service        Two year               No
# 1521                   No        One year               No
# 505                   Yes  Month-to-month              Yes
#
#                 PaymentMethod MonthlyCharges  TotalCharges Churn
# 5572  Credit card (automatic)          74.80        5315.8    No
# 1841         Electronic check          24.30        1261.7    No
# 2041             Mailed check          19.45        165.35    No
# 1521         Electronic check          67.45        2443.3    No
# 505          Electronic check          94.10        1782.4   Yes
#
# [5 rows x 21 columns]

# %%
profile = ProfileReport(df,title = 'Dataset Report')

# %%
profile.to_file('report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# %|                                                                                           | 0/21 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 43.73it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
